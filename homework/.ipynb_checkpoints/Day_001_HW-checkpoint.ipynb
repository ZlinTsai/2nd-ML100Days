# %% [markdown]
# ## Homework 1
#
# #### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估

# %% [markdown]
# 1) 我找的是遊戲銷售量的紀錄[here](https://www.kaggle.com/gregorut/videogamesales)，我很好奇賣座的遊戲類型，是否會隨著時代的不同而有所改變。
#
# 2) 資料來源為VGChartz，但VGChartz的遊戲銷售量是用推測的，根據他們官網的[技術聲明稿](http://www.vgchartz.com/article/629/where-do-vg-chartz-north-american-numbers-come-from/)，他們無法釋出演算法，但他們主要是透過零售商的數據推廣到全地區的數據，因此熱門的遊戲會有比較高的可信度。
#
# 3) 資料型態為結構化的表格，Kaggle提供的是到2016/10/26的收集結果，因此我使用Kaggle提供的爬蟲程式，更新到2019/4/16的資料。
#
# 4) 而最終目的是找到一個符合現在趨勢的遊戲類型，由於遊戲類型是離散的，為一個分類問題，使用cross entropy。

# %%
import numpy as np
import pandas as pd


MyFile = '../data/vgsales_2019.csv'
if ( os.path.isfile(MyFile) ):

        df = pd.read_csv(MyFile)
        print(df.head())
# Out:
#    Rank                           Name Platform    Year     Genre  \
# 0     1                     Wii Sports      Wii  2006.0    Sports
# 1     2              Super Mario Bros.      NES  1985.0  Platform
# 2     3                 Mario Kart Wii      Wii  2008.0    Racing
# 3     4  PlayerUnknown's Battlegrounds       PC  2017.0   Shooter
# 4     5              Wii Sports Resort      Wii  2009.0    Sports
#
#             Publisher           Developer  Critic_Score  User_Score  NA_Sales  \
# 0          Nintendo        Nintendo EAD             7.7         NaN     41.36
# 1          Nintendo        Nintendo EAD            10.0         8.2     29.08
# 2          Nintendo        Nintendo EAD             8.2         9.1     15.91
# 3  PUBG Corporation    PUBG Corporation             NaN         NaN       NaN
# 4          Nintendo        Nintendo EAD             8.0         8.8     15.61
#
#    PAL_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      29.02      3.77         8.51         82.65
# 1       3.58      6.81         0.77         40.24
# 2      12.92      3.80         3.35         35.98
# 3        NaN       NaN          NaN           NaN
# 4      10.99      3.29         3.02         32.90

# %% [markdown]
# ## Homework 2
#
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# 1) 面對現在的大環境競爭，我認為提升服務品質是提升業績的主要關鍵，並提升能見度、塑造品牌形象，增加消費者的信賴感。
#
# 2) 首先，根據乘客上、下車的地點，分析乘客的喜好並精準投放到相關的地方或網站。接著建立自家APP，提供叫車服務與乘客搭乘意見問卷，設立紅利吸引問卷的填答，並根據問卷增進車隊品質。並分析搭車的熱門地段，設立駐點站，吸引新客源，且根據熱門程度決定駐點的車數，達到開源節流。
#
# 3) 結構化的資料型態，根據熱門地點預測駐車數量。根據乘客回饋，標記不良的司機。
#
# 4) 根據業績調整駐車參數。

# %% [markdown]
# ## Homework 3
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# $ MAR = \frac{1}{n}\sum_{i=1}^{n}{|Y_i - \hat{Y}_i|} $

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    
    n = len(y)
    mse = 1/n * ( (y - y_hat)**2 ).sum()
    
    return mse

def mean_absolute_error(y, y_hat):
    
    n = len(y)
    mae = 1/n * ( np.abs(y - y_hat) ).sum()
    
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 252.961
# The Mean absolute error is 12.026

# %%
# https://github.com/GregorUT/vgchartzScrape
from bs4 import BeautifulSoup, element
import urllib
import pandas as pd
import numpy as np
import time

pages = 19
rec_count = 0
total_game = 500
rank = []
gname = []
platform = []
year = []
genre = []
critic_score = []
user_score = []
publisher = []
developer = []
sales_na = []
sales_pal = []
sales_jp = []
sales_ot = []
sales_gl = []

urlhead = 'http://www.vgchartz.com/gamedb/?page='
urltail = '&console=&region=All&developer=&publisher=&genre=&boxart=Both&ownership=Both'
urltail += '&results=1000&order=Sales&showtotalsales=0&showtotalsales=1&showpublisher=0'
urltail += '&showpublisher=1&showvgchartzscore=0&shownasales=1&showdeveloper=1&showcriticscore=1'
urltail += '&showpalsales=0&showpalsales=1&showreleasedate=1&showuserscore=1&showjapansales=1'
urltail += '&showlastupdate=0&showothersales=1&showgenre=1&sort=GL'

for page in range(1, pages):
        
    if (rec_count >= total_game):
        break
    
    surl = urlhead + str(page) + urltail
    r = urllib.request.urlopen(surl).read()
    soup = BeautifulSoup(r)
    print(f"Page: {page}")

    # vgchartz website is really weird so we have to search for
    # <a> tags with game urls
    game_tags = list(filter(
        lambda x: x.attrs['href'].startswith('http://www.vgchartz.com/game/'),
        # discard the first 10 elements because those
        # links are in the navigation bar
        soup.find_all("a")
    ))[10:]

    
    for tag in game_tags:

        # add name to list
        gname.append(" ".join(tag.string.split()))
        print(f"{rec_count + 1} Fetch data for game {gname[-1]}")

        # get different attributes
        # traverse up the DOM tree
        data = tag.parent.parent.find_all("td")
        rank.append(np.int32(data[0].string))
        platform.append(data[3].find('img').attrs['alt'])
        publisher.append(data[4].string)
        developer.append(data[5].string)
        critic_score.append(
            float(data[6].string) if
            not data[6].string.startswith("N/A") else np.nan)
        user_score.append(
            float(data[7].string) if
            not data[7].string.startswith("N/A") else np.nan)
        sales_na.append(
            float(data[9].string[:-1]) if
            not data[9].string.startswith("N/A") else np.nan)
        sales_pal.append(
            float(data[10].string[:-1]) if
            not data[10].string.startswith("N/A") else np.nan)
        sales_jp.append(
            float(data[11].string[:-1]) if
            not data[11].string.startswith("N/A") else np.nan)
        sales_ot.append(
            float(data[12].string[:-1]) if
            not data[12].string.startswith("N/A") else np.nan)
        sales_gl.append(
            float(data[8].string[:-1]) if
            not data[8].string.startswith("N/A") else np.nan)
        release_year = data[13].string.split()[-1]
        # different format for year
        if release_year.startswith('N/A'):
            year.append('N/A')
        else:
            if int(release_year) >= 80:
                year_to_add = np.int32("19" + release_year)
            else:
                year_to_add = np.int32("20" + release_year)
            year.append(year_to_add)

        # go to every individual website to get genre info
        url_to_game = tag.attrs['href']
        site_raw = urllib.request.urlopen(url_to_game).read()
        sub_soup = BeautifulSoup(site_raw, "html.parser")
        # again, the info box is inconsistent among games so we
        # have to find all the h2 and traverse from that to the genre name
        h2s = sub_soup.find("div", {"id": "gameGenInfoBox"}).find_all('h2')
        # make a temporary tag here to search for the one that contains
        # the word "Genre"
        temp_tag = element.Tag
        for h2 in h2s:
            if h2.string == 'Genre':
                temp_tag = h2
        genre.append(temp_tag.next_sibling.string)

        rec_count += 1
        
        time.sleep(30) # avoid HTTP 429 problem
        
        if (rec_count >= total_game):
            break
        else:
            time.sleep(30) # avoid HTTP 429 problem

columns = {
    'Rank': rank,
    'Name': gname,
    'Platform': platform,
    'Year': year,
    'Genre': genre,
    'Critic_Score': critic_score,
    'User_Score': user_score,
    'Publisher': publisher,
    'Developer': developer,
    'NA_Sales': sales_na,
    'PAL_Sales': sales_pal,
    'JP_Sales': sales_jp,
    'Other_Sales': sales_ot,
    'Global_Sales': sales_gl
}

df = pd.DataFrame(columns)
print(df.columns)
df = df[[
    'Rank', 'Name', 'Platform', 'Year', 'Genre',
    'Publisher', 'Developer', 'Critic_Score', 'User_Score',
    'NA_Sales', 'PAL_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']]
df.to_csv("../data/vgsales_2019.csv", sep=",", encoding='utf-8', index=False)
# Out:
# Page: 1
# 1 Fetch data for game Wii Sports
# 2 Fetch data for game Super Mario Bros.
# 3 Fetch data for game Mario Kart Wii
# 4 Fetch data for game PlayerUnknown's Battlegrounds
# 5 Fetch data for game Wii Sports Resort
# 6 Fetch data for game Pokémon Red / Green / Blue Version
# 7 Fetch data for game New Super Mario Bros.
# 8 Fetch data for game Tetris
# 9 Fetch data for game New Super Mario Bros. Wii
# 10 Fetch data for game Minecraft
# 11 Fetch data for game Duck Hunt
# 12 Fetch data for game Wii Play
# 13 Fetch data for game Kinect Adventures!
# 14 Fetch data for game Nintendogs
# 15 Fetch data for game Mario Kart DS
# 16 Fetch data for game Pokémon Gold / Silver Version
# 17 Fetch data for game Wii Fit
# 18 Fetch data for game Wii Fit Plus
# 19 Fetch data for game Super Mario World
# 20 Fetch data for game Grand Theft Auto V
# 21 Fetch data for game Grand Theft Auto V
# 22 Fetch data for game Brain Age: Train Your Brain in Minutes a Day
# 23 Fetch data for game Garry's Mod
# 24 Fetch data for game Super Mario Land
# 25 Fetch data for game Mario Kart 7
# 26 Fetch data for game Pokémon Diamond / Pearl Version
# 27 Fetch data for game Grand Theft Auto: San Andreas
# 28 Fetch data for game Super Mario Bros. 3
# 29 Fetch data for game Pokémon X/Y
# 30 Fetch data for game Pokémon Ruby / Sapphire Version
# 31 Fetch data for game Grand Theft Auto: Vice City
# 32 Fetch data for game Pokémon Sun/Moon
# 33 Fetch data for game Grand Theft Auto V
# 34 Fetch data for game Pokémon Black / White Version
# 35 Fetch data for game Call of Duty: Black Ops 3
# 36 Fetch data for game Mario Kart 8 Deluxe
# 37 Fetch data for game Counter-Strike: Source
# 38 Fetch data for game Sonic the Hedgehog
# 39 Fetch data for game Gran Turismo 3: A-Spec
# 40 Fetch data for game Brain Age 2: More Training in Minutes a Day
# 41 Fetch data for game Call of Duty: Modern Warfare 3
# 42 Fetch data for game Call of Duty: Black Ops
# 43 Fetch data for game Pokémon Yellow: Special Pikachu Edition
# 44 Fetch data for game Halo 3
# 45 Fetch data for game Pokémon Omega Ruby/Pokémon Alpha Sapphire
# 46 Fetch data for game Red Dead Redemption 2
# 47 Fetch data for game Call of Duty: Black Ops II
# 48 Fetch data for game Call of Duty: Black Ops II
# 49 Fetch data for game Super Mario Odyssey
# 50 Fetch data for game Call of Duty: Modern Warfare 2
# 51 Fetch data for game Call of Duty: WWII
# 52 Fetch data for game Call of Duty: Modern Warfare 3
# 53 Fetch data for game Super Smash Bros. Brawl
# 54 Fetch data for game Grand Theft Auto III
# 55 Fetch data for game New Super Mario Bros. 2
# 56 Fetch data for game Portal 2
# 57 Fetch data for game Minecraft
# 58 Fetch data for game Super Mario Galaxy
# 59 Fetch data for game Pokémon Heart Gold / Soul Silver Version
# 60 Fetch data for game Call of Duty: Black Ops
# 61 Fetch data for game Grand Theft Auto V
# 62 Fetch data for game Super Mario 3D Land
# 63 Fetch data for game Animal Crossing: New Leaf
# 64 Fetch data for game Super Smash Bros. Ultimate
# 65 Fetch data for game Diablo III
# 66 Fetch data for game Pokémon FireRed / LeafGreen Version
# 67 Fetch data for game Gran Turismo 5
# 68 Fetch data for game Super Mario 64
# 69 Fetch data for game FIFA 18
# 70 Fetch data for game Gran Turismo 4
# 71 Fetch data for game Animal Crossing: Wild World
# 72 Fetch data for game The Legend of Zelda: Breath of the Wild
# 73 Fetch data for game Super Mario Land 2: 6 Golden Coins
# 74 Fetch data for game Grand Theft Auto IV
# 75 Fetch data for game Super Mario 64 DS
# 76 Fetch data for game Terraria
# 77 Fetch data for game FIFA 17
# 78 Fetch data for game Gran Turismo
# 79 Fetch data for game Call of Duty: Modern Warfare 2
# 80 Fetch data for game Grand Theft Auto IV
# 81 Fetch data for game Super Mario All-Stars
# 82 Fetch data for game Call of Duty: Ghosts
# 83 Fetch data for game Just Dance 3
# 84 Fetch data for game Call of Duty: Ghosts
# 85 Fetch data for game Horizon: Zero Dawn
# 86 Fetch data for game Pokémon: Let's Go, Pikachu/Eevee
# 87 Fetch data for game RollerCoaster Tycoon 3
# 88 Fetch data for game Halo: Reach
# 89 Fetch data for game Portal
# 90 Fetch data for game Halo 4
# 91 Fetch data for game Final Fantasy VII
# 92 Fetch data for game Mario Kart 64
# 93 Fetch data for game StarCraft
# 94 Fetch data for game Super Smash Bros. for 3DS
# 95 Fetch data for game Call of Duty 4: Modern Warfare
# 96 Fetch data for game Gran Turismo 2
# 97 Fetch data for game Wii Party
# 98 Fetch data for game Call of Duty: Black Ops IIII
# 99 Fetch data for game Mario Party DS
# 100 Fetch data for game Donkey Kong Country
# 101 Fetch data for game FIFA 19
# 102 Fetch data for game Rust
# 103 Fetch data for game Marvel's Spider-Man
# 104 Fetch data for game Half-Life 2
# 105 Fetch data for game The Elder Scrolls V: Skyrim
# 106 Fetch data for game Mario Party 8
# 107 Fetch data for game Super Mario Kart
# 108 Fetch data for game Grand Theft Auto V
# 109 Fetch data for game Uncharted 4: A Thief's End
# 110 Fetch data for game Final Fantasy VIII
# 111 Fetch data for game Final Fantasy X
# 112 Fetch data for game Pokémon Black 2 and White 2
# 113 Fetch data for game Call of Duty: Infinite Warfare
# 114 Fetch data for game Fallout 4
# 115 Fetch data for game Mario Kart 8
# 116 Fetch data for game Tekken 3
# 117 Fetch data for game Pokémon: Ultra Sun and Ultra Moon
# 118 Fetch data for game Splatoon 2
# 119 Fetch data for game FIFA 16
# 120 Fetch data for game GoldenEye 007
# 121 Fetch data for game Star Wars Battlefront (2015)
# 122 Fetch data for game FIFA 13
# 123 Fetch data for game Halo 2
# 124 Fetch data for game The Sims 3
# 125 Fetch data for game Grand Theft Auto: Liberty City Stories
# 126 Fetch data for game Pac-Man
# 127 Fetch data for game Pokémon Platinum Version
# 128 Fetch data for game The Legend of Zelda: Ocarina of Time
# 129 Fetch data for game Crash Bandicoot 2: Cortex Strikes Back
# 130 Fetch data for game Call of Duty: Advanced Warfare
# 131 Fetch data for game Call of Duty: World at War
# 132 Fetch data for game Super Mario Bros. 2
# 133 Fetch data for game Super Mario Galaxy 2
# 134 Fetch data for game Super Smash Bros. Melee
# 135 Fetch data for game Call of Duty: Black Ops 3
# 136 Fetch data for game Battlefield 3
# 137 Fetch data for game The Legend of Zelda: Twilight Princess
# 138 Fetch data for game Battlefield 1
# 139 Fetch data for game Battlefield 3
# 140 Fetch data for game Need for Speed Underground
# 141 Fetch data for game The Binding of Isaac
# 142 Fetch data for game Crash Bandicoot 3: Warped
# 143 Fetch data for game Pokémon Emerald Version
# 144 Fetch data for game Yokai Watch 2: Bony Spirits / Fleshy Souls / Psychic Specters
# 145 Fetch data for game Need for Speed Underground 2
# 146 Fetch data for game Just Dance 4
# 147 Fetch data for game Mario Kart: Double Dash!!
# 148 Fetch data for game Uncharted 3: Drake's Deception
# 149 Fetch data for game Medal of Honor: Frontline
# 150 Fetch data for game Crash Bandicoot
# 151 Fetch data for game Zumba Fitness
# 152 Fetch data for game Uncharted 2: Among Thieves
# 153 Fetch data for game Call of Duty 4: Modern Warfare
# 154 Fetch data for game FIFA Soccer 12
# 155 Fetch data for game FIFA 14
# 156 Fetch data for game Red Dead Redemption
# 157 Fetch data for game Donkey Kong Country Returns
# 158 Fetch data for game The Legend of Zelda
# 159 Fetch data for game Assassin's Creed III
# 160 Fetch data for game Guild Wars
# 161 Fetch data for game Red Dead Redemption
# 162 Fetch data for game The Elder Scrolls V: Skyrim
# 163 Fetch data for game Final Fantasy XII
# 164 Fetch data for game Tomodachi Life
# 165 Fetch data for game Pokémon Crystal Version
# 166 Fetch data for game Halo 3: ODST
# 167 Fetch data for game Minecraft
# 168 Fetch data for game FIFA 15
# 169 Fetch data for game Kingdom Hearts
# 170 Fetch data for game Street Fighter II: The World Warrior
# 171 Fetch data for game The Last of Us
# 172 Fetch data for game Driver
# 173 Fetch data for game Call of Duty: WWII
# 174 Fetch data for game God of War (2018)
# 175 Fetch data for game Big Brain Academy
# 176 Fetch data for game Minecraft
# 177 Fetch data for game Metal Gear Solid 2: Sons of Liberty
# 178 Fetch data for game Metal Gear Solid
# 179 Fetch data for game Myst
# 180 Fetch data for game Sonic the Hedgehog 2
# 181 Fetch data for game Metal Gear Solid 4: Guns of the Patriots
# 182 Fetch data for game Euro Truck Simulator 2
# 183 Fetch data for game Mario Kart: Super Circuit
# 184 Fetch data for game Super Mario Sunshine
# 185 Fetch data for game LittleBigPlanet
# 186 Fetch data for game Age of Empires II: HD Edition
# 187 Fetch data for game Super Mario 3D World
# 188 Fetch data for game Link's Crossbow Training
# 189 Fetch data for game Red Dead Redemption 2
# 190 Fetch data for game New Super Mario Bros. U
# 191 Fetch data for game Destiny
# 192 Fetch data for game Luigi's Mansion: Dark Moon
# 193 Fetch data for game Tekken 2
# 194 Fetch data for game Uncharted: The Nathan Drake Collection
# 195 Fetch data for game Super Mario World: Super Mario Advance 2
# 196 Fetch data for game LEGO Star Wars: The Complete Saga
# 197 Fetch data for game Cooking Mama
# 198 Fetch data for game The Legend of Zelda: Ocarina of Time 3D
# 199 Fetch data for game Tetris
# 200 Fetch data for game Super Mario Advance
# 201 Fetch data for game Assassin's Creed II
# 202 Fetch data for game Super Smash Bros.
# 203 Fetch data for game Assassin's Creed
# 204 Fetch data for game Batman: Arkham City
# 205 Fetch data for game Forza Motorsport 3
# 206 Fetch data for game Dragon Quest IX: Sentinels of the Starry Skies
# 207 Fetch data for game Final Fantasy IX
# 208 Fetch data for game Final Fantasy X-2
# 209 Fetch data for game Tomb Raider (2013)
# 210 Fetch data for game The Witcher 3: Wild Hunt
# 211 Fetch data for game Pokémon Stadium
# 212 Fetch data for game Minecraft
# 213 Fetch data for game Call of Duty: World at War
# 214 Fetch data for game Super Mario Advance 4: Super Mario Bros. 3
# 215 Fetch data for game Crash Bandicoot: The Wrath of Cortex
# 216 Fetch data for game The Witcher 3: Wild Hunt
# 217 Fetch data for game Final Fantasy XIII
# 218 Fetch data for game Gran Turismo 5 Prologue
# 219 Fetch data for game Super Smash Bros. for Wii U
# 220 Fetch data for game Dr. Mario
# 221 Fetch data for game Assassin's Creed III
# 222 Fetch data for game Pokémon Pinball
# 223 Fetch data for game Assassin's Creed II
# 224 Fetch data for game Super Mario Party
# 225 Fetch data for game The Forest
# 226 Fetch data for game Donkey Kong 64
# 227 Fetch data for game Just Dance 2
# 228 Fetch data for game Tomb Raider II
# 229 Fetch data for game Madden NFL 2004
# 230 Fetch data for game Call of Duty: Advanced Warfare
# 231 Fetch data for game Fallout: New Vegas
# 232 Fetch data for game Gran Turismo 6
# 233 Fetch data for game Kingdom Hearts II
# 234 Fetch data for game God of War III
# 235 Fetch data for game Nintendo Land
# 236 Fetch data for game Super Mario Land 3: Wario Land
# 237 Fetch data for game Donkey Kong Country 2: Diddy's Kong Quest
# 238 Fetch data for game Medal of Honor: Rising Sun
# 239 Fetch data for game Battlefield 1
# 240 Fetch data for game Kirby's Dream Land
# 241 Fetch data for game Microsoft Flight Simulator
# 242 Fetch data for game Guitar Hero II
# 243 Fetch data for game FIFA 13
# 244 Fetch data for game Resident Evil 5
# 245 Fetch data for game Fable III
# 246 Fetch data for game Mario & Sonic at the Olympic Games
# 247 Fetch data for game Grand Theft Auto: Vice City Stories
# 248 Fetch data for game FIFA Soccer 11
# 249 Fetch data for game Super Mario Bros. Deluxe
# 250 Fetch data for game Final Fantasy XV
# 251 Fetch data for game Fallout 4
# 252 Fetch data for game Tony Hawk's Pro Skater
# 253 Fetch data for game Warzone 2100
# 254 Fetch data for game Spyro the Dragon
# 255 Fetch data for game Cities: Skylines
# 256 Fetch data for game Gears of War
# 257 Fetch data for game Gears of War 2
# 258 Fetch data for game Guild Wars 2
# 259 Fetch data for game Halo 5: Guardians
# 260 Fetch data for game Halo: Combat Evolved
# 261 Fetch data for game Guitar Hero III: Legends of Rock
# 262 Fetch data for game Uncharted: Drake's Fortune
# 263 Fetch data for game Resident Evil 2
# 264 Fetch data for game Fallout 3
# 265 Fetch data for game Splatoon
# 266 Fetch data for game Madden NFL 06
# 267 Fetch data for game Stardew Valley
# 268 Fetch data for game Dragon Quest VIII: Journey of the Cursed King
# 269 Fetch data for game Monster Hunter Freedom 3
# 270 Fetch data for game Diddy Kong Racing
# 271 Fetch data for game Pokémon Mystery Dungeon: Explorers of Time / Darkness
# 272 Fetch data for game Call of Duty: Black Ops IIII
# 273 Fetch data for game Dr. Mario
# 274 Fetch data for game Crash Bandicoot N. Sane Trilogy
# 275 Fetch data for game Assassin's Creed
# 276 Fetch data for game Call of Duty: Infinite Warfare
# 277 Fetch data for game Crash Team Racing
# 278 Fetch data for game LEGO Star Wars: The Complete Saga
# 279 Fetch data for game The Legend of Zelda: Phantom Hourglass
# 280 Fetch data for game Batman: Arkham City
# 281 Fetch data for game Driver 2
# 282 Fetch data for game The Simpsons: Hit & Run
# 283 Fetch data for game World of Warcraft: Cataclysm
# 284 Fetch data for game Tony Hawk's Pro Skater 2
# 285 Fetch data for game Monster Hunter: World
# 286 Fetch data for game Gran Turismo
# 287 Fetch data for game The Lord of the Rings: The Two Towers
# 288 Fetch data for game Tomb Raider
# 289 Fetch data for game God of War
# 290 Fetch data for game The Legend of Zelda: A Link to the Past
# 291 Fetch data for game Forza Motorsport 4
# 292 Fetch data for game Guitar Hero III: Legends of Rock
# 293 Fetch data for game Pokémon: Let's Go, Pikachu!
# 294 Fetch data for game BioShock Infinite
# 295 Fetch data for game Mario & Luigi: Bowser's Inside Story
# 296 Fetch data for game FIFA 15
# 297 Fetch data for game Mario & Sonic at the Olympic Winter Games
# 298 Fetch data for game Overwatch
# 299 Fetch data for game Madden NFL 2005
# 300 Fetch data for game Guitar Hero III: Legends of Rock
# 301 Fetch data for game Star Wars Battlefront II (2017)
# 302 Fetch data for game Dead Island
# 303 Fetch data for game Arma 2: Operation Arrowhead
# 304 Fetch data for game ARK: Survival Evolved
# 305 Fetch data for game Riven: The Sequel to Myst
# 306 Fetch data for game StarCraft II: Wings of Liberty
# 307 Fetch data for game Warcraft III: Reign of Chaos
# 308 Fetch data for game Pitfall!
# 309 Fetch data for game Professor Layton and the Curious Village
# 310 Fetch data for game Madden NFL 07
# 311 Fetch data for game Spider-Man: The Movie
# 312 Fetch data for game Nintendogs + cats
# 313 Fetch data for game The Elder Scrolls IV: Oblivion
# 314 Fetch data for game The Legend of Zelda: The Wind Waker
# 315 Fetch data for game Tony Hawk's Pro Skater 3
# 316 Fetch data for game Winning Eleven: Pro Evolution Soccer 2007
# 317 Fetch data for game Zelda II: The Adventure of Link
# 318 Fetch data for game Michael Jackson: The Experience
# 319 Fetch data for game Tom Clancy's The Division
# 320 Fetch data for game Need for Speed: Most Wanted
# 321 Fetch data for game Resistance: Fall of Man
# 322 Fetch data for game Tom Clancy's Rainbow Six: Siege
# 323 Fetch data for game Call of Duty: Advanced Warfare
# 324 Fetch data for game Watch Dogs
# 325 Fetch data for game Animal Crossing: City Folk
# 326 Fetch data for game Starbound
# 327 Fetch data for game Asteroids
# 328 Fetch data for game Dragon Quest VII
# 329 Fetch data for game Monster Hunter Generations
# 330 Fetch data for game Batman: Arkham Asylum
# 331 Fetch data for game Call of Duty: Advanced Warfare
# 332 Fetch data for game God of War II
# 333 Fetch data for game Namco Museum
# 334 Fetch data for game Daxter
# 335 Fetch data for game Super Paper Mario
# 336 Fetch data for game Assassin's Creed: Revelations
# 337 Fetch data for game Metal Gear Solid 3: Snake Eater
# 338 Fetch data for game Assassin's Creed: Revelations
# 339 Fetch data for game FIFA Soccer 06
# 340 Fetch data for game Monster Hunter 4 Ultimate
# 341 Fetch data for game Street Fighter IV
# 342 Fetch data for game 7 Days to Die
# 343 Fetch data for game FIFA Soccer 12
# 344 Fetch data for game Call of Duty: Ghosts
# 345 Fetch data for game Teenage Mutant Ninja Turtles
# 346 Fetch data for game Just Cause 2
# 347 Fetch data for game Excitebike
# 348 Fetch data for game Frogger
# 349 Fetch data for game Star Wars Battlefront (2015)
# 350 Fetch data for game FIFA 14
# 351 Fetch data for game Madden NFL 2003
# 352 Fetch data for game Assassin's Creed: Unity
# 353 Fetch data for game Destiny 2
# 354 Fetch data for game Half-Life
# 355 Fetch data for game Super Mario World 2: Yoshi's Island
# 356 Fetch data for game Batman: Arkham Knight
# 357 Fetch data for game FIFA 07 Soccer
# 358 Fetch data for game The Sims 4
# 359 Fetch data for game Monster Hunter 4
# 360 Fetch data for game Street Fighter II Turbo
# 361 Fetch data for game Fallout: New Vegas
# 362 Fetch data for game Assassin's Creed Origins
# 363 Fetch data for game Far Cry 4
# 364 Fetch data for game Carnival Games
# 365 Fetch data for game World Soccer Winning Eleven 9
# 366 Fetch data for game Forza Motorsport 2
# 367 Fetch data for game Namco Museum Vol.3
# 368 Fetch data for game Tekken Tag Tournament
# 369 Fetch data for game Golf
# 370 Fetch data for game Diablo II
# 371 Fetch data for game Disney's Aladdin
# 372 Fetch data for game EyeToy Play
# 373 Fetch data for game Just Dance
# 374 Fetch data for game Star Fox 64
# 375 Fetch data for game Super Mario Maker
# 376 Fetch data for game World of Warcraft: Wrath of the Lich King
# 377 Fetch data for game Fallout 3
# 378 Fetch data for game The Legend of Zelda: Oracle of Ages / Seasons
# 379 Fetch data for game The Elder Scrolls V: Skyrim
# 380 Fetch data for game Namco Museum: 50th Anniversary
# 381 Fetch data for game NBA 2K16
# 382 Fetch data for game Left 4 Dead 2
# 383 Fetch data for game Far Cry 5
# 384 Fetch data for game Battlefield 4
# 385 Fetch data for game Assassin's Creed IV: Black Flag
# 386 Fetch data for game EA Sports Active
# 387 Fetch data for game Half-Life 2: Episode One
# 388 Fetch data for game Donkey Kong Land
# 389 Fetch data for game English Training: Have Fun Improving Your Skills!
# 390 Fetch data for game Dragon Quest III
# 391 Fetch data for game Tony Hawk's Underground
# 392 Fetch data for game Just Dance 2014
# 393 Fetch data for game Professor Layton and the Diabolical Box
# 394 Fetch data for game Sports Champions
# 395 Fetch data for game MotorStorm
# 396 Fetch data for game World Soccer Winning Eleven 8 International
# 397 Fetch data for game Namco Museum Vol.1
# 398 Fetch data for game The Legend of Zelda: Link's Awakening
# 399 Fetch data for game Resident Evil VII: Biohazard
# 400 Fetch data for game Monster Hunter Freedom Unite
# 401 Fetch data for game Gran Turismo Sport
# 402 Fetch data for game LEGO Indiana Jones: The Original Adventures
# 403 Fetch data for game The Sims: Unleashed
# 404 Fetch data for game Tomodachi Collection
# 405 Fetch data for game Ratchet & Clank: Size Matters
# 406 Fetch data for game Harry Potter and the Sorcerer's Stone
# 407 Fetch data for game Pokémon Trading Card Game
# 408 Fetch data for game FIFA 17
# 409 Fetch data for game Spyro: Year of the Dragon
# 410 Fetch data for game The Legend of Zelda: A Link Between Worlds
# 411 Fetch data for game FIFA Soccer 2005
# 412 Fetch data for game Diablo III: Reaper of Souls
# 413 Fetch data for game The Legend of Zelda: Skyward Sword
# 414 Fetch data for game Tony Hawk's Pro Skater 4
# 415 Fetch data for game Midnight Club 3: DUB Edition
# 416 Fetch data for game MySims
# 417 Fetch data for game Banjo-Kazooie
# 418 Fetch data for game SOCOM: U.S. Navy SEALs
# 419 Fetch data for game Battlefield 4
# 420 Fetch data for game Jak and Daxter: The Precursor Legacy
# 421 Fetch data for game Pokémon Snap
# 422 Fetch data for game Pro Evolution Soccer 2008
# 423 Fetch data for game FIFA Soccer 10
# 424 Fetch data for game Guitar Hero: World Tour
# 425 Fetch data for game Gears of War: Ultimate Edition
# 426 Fetch data for game Star Wars Battlefront
# 427 Fetch data for game Doom II
# 428 Fetch data for game The Simpsons: Road Rage
# 429 Fetch data for game BattleBlock Theater
# 430 Fetch data for game Assassin's Creed Syndicate
# 431 Fetch data for game Star Wars Battlefront II
# 432 Fetch data for game Assassin's Creed: Unity
# 433 Fetch data for game Cooking Mama 2: Dinner With Friends
# 434 Fetch data for game Undertale
# 435 Fetch data for game WWF SmackDown!
# 436 Fetch data for game Croc: Legend of the Gobbos
# 437 Fetch data for game Battlefield 4
# 438 Fetch data for game Grand Theft Auto: Liberty City Stories
# 439 Fetch data for game The Getaway
# 440 Fetch data for game Tomb Raider III: Adventures of Lara Croft
# 441 Fetch data for game Batman: Arkham Asylum
# 442 Fetch data for game Assassin's Creed: Brotherhood
# 443 Fetch data for game James Bond 007: Agent Under Fire
# 444 Fetch data for game LEGO Star Wars: The Video Game
# 445 Fetch data for game Resident Evil 5
# 446 Fetch data for game Rugrats in Paris: The Movie
# 447 Fetch data for game NBA 2K17
# 448 Fetch data for game FIFA Soccer 11
# 449 Fetch data for game Spyro 2: Ripto's Rage!
# 450 Fetch data for game Left 4 Dead
# 451 Fetch data for game Donkey Kong Country 3: Dixie Kong's Double Trouble!
# 452 Fetch data for game Fable II
# 453 Fetch data for game Kung Fu
# 454 Fetch data for game Resident Evil 3: Nemesis
# 455 Fetch data for game World of Warcraft: The Burning Crusade
# 456 Fetch data for game FIFA Soccer 2004
# 457 Fetch data for game Pokémon Mystery Dungeon: Blue Rescue Team
# 458 Fetch data for game Mortal Kombat X
# 459 Fetch data for game Battlefield: Bad Company 2
# 460 Fetch data for game Borderlands
# 461 Fetch data for game Mario & Sonic at the Olympic Winter Games
# 462 Fetch data for game Dying Light
# 463 Fetch data for game Guitar Hero: On Tour
# 464 Fetch data for game Dragon Ball Z: Budokai
# 465 Fetch data for game Halo: The Master Chief Collection
# 466 Fetch data for game LEGO Batman: The Videogame
# 467 Fetch data for game Tekken 4
# 468 Fetch data for game FIFA 14
# 469 Fetch data for game LittleBigPlanet 2
# 470 Fetch data for game Grand Theft Auto 2
# 471 Fetch data for game Destiny
# 472 Fetch data for game Spider-Man 2
# 473 Fetch data for game F-1 Race
# 474 Fetch data for game World of Warcraft: Battle for Azeroth
# 475 Fetch data for game FIFA Soccer 2003
# 476 Fetch data for game Crash Bash
# 477 Fetch data for game Gears of War 4
# 478 Fetch data for game Tekken: Dark Resurrection
# 479 Fetch data for game The Elder Scrolls V: Skyrim Special Edition
# 480 Fetch data for game Watch Dogs 2
# 481 Fetch data for game The Legend of Zelda: Majora's Mask
# 482 Fetch data for game WWF War Zone
# 483 Fetch data for game Yoshi's Island DS
# 484 Fetch data for game Assassin's Creed IV: Black Flag
# 485 Fetch data for game NBA 2K18
# 486 Fetch data for game Big Brain Academy: Wii Degree
# 487 Fetch data for game Rugrats: Search For Reptar
# 488 Fetch data for game Luigi's Mansion
# 489 Fetch data for game James Bond 007: Nightfire
# 490 Fetch data for game Ratchet & Clank
# 491 Fetch data for game Animal Crossing: Happy Home Designer
# 492 Fetch data for game Star Wars Episode III: Revenge of the Sith
# 493 Fetch data for game Max Payne
# 494 Fetch data for game Madden NFL 16
# 495 Fetch data for game World of Warcraft: Legion
# 496 Fetch data for game World of Warcraft: Warlords of Draenor
# 497 Fetch data for game Dark Souls III
# 498 Fetch data for game Dark Souls: Prepare to Die Edition
# 499 Fetch data for game The Lord of the Rings: The Return of the King
# 500 Fetch data for game Half-Life 2: Episode Two
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Critic_Score',
#        'User_Score', 'Publisher', 'Developer', 'NA_Sales', 'PAL_Sales',
#        'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')
